# %% [markdown]
# <a href="https://colab.research.google.com/github/skarabayev/Google-Apps-Scripts/blob/master/convert_gs_to_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mount the Drive
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

worksheet = gc.open('Payments').worksheet('Debt')

# %%
# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
print(rows)
# Out:
# [['Дата поступления', 'Отсрочка платежа (дней)', 'Дата Погашения', 'Статья Расходов', 'Наименование поставщика', 'Описание', 'Валюта', 'Курс', 'Сумма по накладной (инвойсу)', 'Сумма к оплате', 'Остаток в Эквиваленте KZT', 'Статус', 'Подразделение', 'Просрочка'], ['', '', '30/06/2023', 'Возврат клиенту ', 'Компания Эврика', 'возврат д/с ', 'KZT', '1', '8\xa0000\xa0000', '8\xa0000\xa0000,00', '₸8\xa0000\xa0000', 'hold', 'Офис', '308'], ['20/11/2023', '90', '17/02/2024', 'Оплата производителям', 'YATAS', 'YIH2023000001046/YIH2023000001047/YIH2023000001048/YIH2023000001049 ot 20.11.2023 - 40W932SA-402055BA', 'USD', '445,95', '21\xa0065', '21\xa0065,38', '₸9\xa0394\xa0106', 'hold', 'Шымкент', '76'], ['21/11/2023', '90', '18/02/2024', 'Оплата производителям', 'YATAS', 'YIH2023000001061/YIH2023000001062/YIH2023000001063/YIH2023000001064 от 21.11.2023 (e-Fatura) - 80S294UA-809553AA', 'USD', '445,95', '29\xa0659', '29\xa0658,85', '₸13\xa0226\xa0364', 'hold', 'Астана', '75'], ['12/12/2023', '9
# ...

# %%
# Convert to a DataFrame and render.
import pandas as pd

pd.DataFrame.from_records(rows)
# Out:
#                    0                        1               2   \
# 0    Дата поступления  Отсрочка платежа (дней)  Дата Погашения
# 1                                                   30/06/2023
# 2          20/11/2023                       90      17/02/2024
# 3          21/11/2023                       90      18/02/2024
# 4          12/12/2023                       90      10/03/2024
# ..                ...                      ...             ...
# 214
# 215
# 216
# 217
# 218                                                 05/05/2024
#
#                         3                        4   \
# 0          Статья Расходов  Наименование поставщика
# 1         Возврат клиенту           Компания Эврика
# 2    Оплата производителям                    YATAS
# 3    Оплата производителям                    YATAS
# 4    Оплата производителям                    YATAS
# ..                     ...                      ...
# 214
# 215
# 216
# 217
# ...
